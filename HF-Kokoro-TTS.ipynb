# %%
# !git clone https://huggingface.co/spaces/hexgrad/Kokoro-TTS
# Out:
# Cloning into 'Kokoro-TTS'...
# remote: Enumerating objects: 774, done.
# remote: Counting objects: 100% (177/177), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 774 (delta 175), reused 172 (delta 172), pack-reused 597 (from 1)
# Receiving objects: 100% (774/774), 1.88 MiB | 2.16 MiB/s, done.
# Resolving deltas: 100% (463/463), done.

# %%
# !pwd
# Out:
# /content

# %%
# %cd Kokoro-TTS
# Out:
# /content/Kokoro-TTS

# %%
# !ls
# Out:
# app.py	frankenstein5k.md  packages.txt  requirements.txt
# en.txt	gatsby5k.md	   README.md

# %%
# !pip install --upgrade pip -q
# !pip uninstall -y cuml-cu12 cudf-cu12 cuda-python
# !pip uninstall -y torch torchaudio torchvision
# !pip install torch==2.10.0 torchaudio==2.10.0 torchvision==0.25.0 -f https://download.pytorch.org/whl/torch_stable.html -q
# !pip install -r requirements.txt -q
# Out:
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 76.7 MB/s eta 0:00:00
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Found existing installation: cuml-cu12 26.2.0
# Uninstalling cuml-cu12-26.2.0:
#   Successfully uninstalled cuml-cu12-26.2.0
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Found existing installation: cudf-cu12 26.2.1
# Uninstalling cudf-cu12-26.2.1:
#   Successfully uninstalled cudf-cu12-26.2.1
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# Found existing installation: cuda-python 12.9.4
# Uninstalling cuda-python-12.9.4:
#   Successfully uninstalled cuda-python-12.9.4
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# ...

# %%
# !pip install gradio
# Out:
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# ...
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)

# %%
# !pip install huggingface_hub
# Out:
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# ...
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)

# %%
import os
os.environ['HF_TOKEN'] = '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'

# Verify it's set (optional)
print('Hugging Face token environment variable set.')
# Out:
# Hugging Face token environment variable set.

# %%
# !pip install spaces -q
# Out:
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)
# WARNING: Ignoring invalid distribution ~orch (/usr/local/lib/python3.12/dist-packages)

# %% [markdown]
# ADD share=True
#
# IN LUNCH launch(show_api=API_OPEN, ssr_mode=True)
#
# make ssr_mode=False
#
#
#     app.queue(api_open=API_OPEN).launch(show_api=API_OPEN, ssr_mode=False, share=True)

# %%
# !python app.py
# Out:
# WARNING: Defaulting repo_id to hexgrad/Kokoro-82M. Pass repo_id='hexgrad/Kokoro-82M' to suppress this warning.
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/rnn.py:990: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.2 and num_layers=1
#   super().__init__("LSTM", *args, **kwargs)
# /usr/local/lib/python3.12/dist-packages/torch/nn/utils/weight_norm.py:144: FutureWarning: `torch.nn.utils.weight_norm` is deprecated in favor of `torch.nn.utils.parametrizations.weight_norm`.
#   WeightNorm.apply(module, name, dim)
# WARNING: Defaulting repo_id to hexgrad/Kokoro-82M. Pass repo_id='hexgrad/Kokoro-82M' to suppress this warning.
# WARNING: Defaulting repo_id to hexgrad/Kokoro-82M. Pass repo_id='hexgrad/Kokoro-82M' to suppress this warning.
# WARNING: Defaulting repo_id to hexgrad/Kokoro-82M. Pass repo_id='hexgrad/Kokoro-82M' to suppress this warning.
# ...
