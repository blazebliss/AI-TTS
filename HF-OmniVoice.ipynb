# %%
# !git clone https://huggingface.co/spaces/k2-fsa/OmniVoice
# Out:
# Cloning into 'OmniVoice'...
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 134 (delta 6), reused 0 (delta 0), pack-reused 102 (from 1)
# Receiving objects: 100% (134/134), 215.77 KiB | 644.00 KiB/s, done.
# Resolving deltas: 100% (38/38), done.

# %%
# !pwd
# Out:
# /content

# %%
# %cd OmniVoice
# Out:
# /content/OmniVoice

# %%
# !ls
# Out:
# app.py	omnivoice  README.md  requirements.txt

# %%
# Removed explicit torch, torchvision, torchaudio installation to avoid conflicts

# %%
# !pip uninstall -y torch torchvision torchaudio
# !pip install torch==2.1.0 torchvision==0.16.0 --index-url https://download.pytorch.org/whl/cu121
# !pip install -r requirements.txt -q
# Out:
# Found existing installation: torch 2.8.0+cu128
# Uninstalling torch-2.8.0+cu128:
#   Successfully uninstalled torch-2.8.0+cu128
# Found existing installation: torchvision 0.20.1+cu121
# Uninstalling torchvision-0.20.1+cu121:
#   Successfully uninstalled torchvision-0.20.1+cu121
# Found existing installation: torchaudio 2.8.0+cu128
# Uninstalling torchaudio-2.8.0+cu128:
#   Successfully uninstalled torchaudio-2.8.0+cu128
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ERROR: Could not find a version that satisfies the requirement torch==2.1.0 (from versions: 2.2.0+cu121, 2.2.1+cu121, 2.2.2+cu121, 2.3.0+cu121, 2.3.1+cu121, 2.4.0+cu121, 2.4.1+cu121, 2.5.0+cu121, 2.5.1+cu121)
# ERROR: No matching distribution found for torch==2.1.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# timm 1.0.26 requires torchvision, which is not installed.
# ...

# %%
# !pip install gradio

# %%
# !pip install huggingface_hub

# %%
import os
os.environ['HF_TOKEN'] = '[ENTER TOKEN HERE]'

# Verify it's set (optional)
print('Hugging Face token environment variable set.')
# Out:
# Hugging Face token environment variable set.

# %%
# !pip install spaces -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.5/107.5 kB 8.8 MB/s eta 0:00:00

# %% [markdown]
# ADD share=True
#
# TO launch()

# %%
# !python app.py
# Out:
# Loading model from k2-fsa/OmniVoice to cuda ...
# Loading weights: 100% 313/313 [00:07<00:00, 39.41it/s]
# ...
# Fetching 13 files: 100% 13/13 [00:00<00:00, 115521.08it/s]
# Download complete: : 0.00B [00:01, ?B/s]
# Loading weights: 100% 527/527 [00:02<00:00, 185.11it/s]
# Loading weights: 100% 587/587 [00:05<00:00, 106.64it/s]
# Model loaded successfully!
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://45a8bef34888c15c1d.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# 2026-04-22 12:47:38,554 omnivoice.models.omnivoice DEBUG: Item 0 — text: A bed is where you lie down to rest and sleep. | ref_text: A key is a small tool used to open doors or locks. | instruct: None | lang: en | target_tokens: 101
# ...
