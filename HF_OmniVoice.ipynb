# %%
# @title
# !git clone https://huggingface.co/spaces/k2-fsa/OmniVoice
# Out:
# Cloning into 'OmniVoice'...
# remote: Enumerating objects: 134, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (30/30), done.
# remote: Total 134 (delta 6), reused 0 (delta 0), pack-reused 102 (from 1)
# Receiving objects: 100% (134/134), 215.77 KiB | 2.63 MiB/s, done.
# Resolving deltas: 100% (38/38), done.

# %%
# @title
# !pwd
# Out:
# /content

# %%
# @title
# %cd OmniVoice
# Out:
# /content/OmniVoice

# %%
# @title
# !ls
# Out:
# app.py	omnivoice  README.md  requirements.txt

# %%
# Removed explicit torch, torchvision, torchaudio installation to avoid conflicts

# %%
# @title
# !pip uninstall -y torch torchvision torchaudio
# !pip install torch==2.1.0 torchvision==0.16.0 --index-url https://download.pytorch.org/whl/cu121
# !pip install -r requirements.txt -q
# Out:
# Found existing installation: torch 2.10.0+cu128
# Uninstalling torch-2.10.0+cu128:
#   Successfully uninstalled torch-2.10.0+cu128
# Found existing installation: torchvision 0.25.0+cu128
# Uninstalling torchvision-0.25.0+cu128:
#   Successfully uninstalled torchvision-0.25.0+cu128
# Found existing installation: torchaudio 2.10.0+cu128
# Uninstalling torchaudio-2.10.0+cu128:
#   Successfully uninstalled torchaudio-2.10.0+cu128
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ERROR: Could not find a version that satisfies the requirement torch==2.1.0 (from versions: 2.2.0+cu121, 2.2.1+cu121, 2.2.2+cu121, 2.3.0+cu121, 2.3.1+cu121, 2.4.0+cu121, 2.4.1+cu121, 2.5.0+cu121, 2.5.1+cu121)
# ERROR: No matching distribution found for torch==2.1.0
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.4/322.4 MB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 889.0/889.0 MB 1.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 82.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.7/10.7 MB 101.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.6/155.6 MB 6.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 121.1 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# timm 1.0.26 requires torchvision, which is not installed.
# fastai 2.8.7 requires torchvision>=0.11, which is not installed.

# %%
# @title
import os
os.environ['HF_TOKEN'] = ''

# Verify it's set (optional)
print('Hugging Face token environment variable set.')
# Out:
# Hugging Face token environment variable set.

# %%
# @title
# !pip install spaces -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 107.5/107.5 kB 5.9 MB/s eta 0:00:00

# %%
# @title
with open('/content/OmniVoice/app.py', 'r') as f:
      print(f.read())
# Out:
# #!/usr/bin/env python3
# """
# HuggingFace Space entry point for OmniVoice demo.
#
# """
#
# import logging
# import os
# from typing import Any, Dict
#
# logging.basicConfig(
#     level=logging.WARNING,
#     format="%(asctime)s %(name)s %(levelname)s: %(message)s",
# )
# logging.getLogger("omnivoice").setLevel(logging.DEBUG)
#
# import numpy as np
# import spaces
# import torch
# from omnivoice import OmniVoice, OmniVoiceGenerationConfig
# from omnivoice.cli.demo import build_demo
#
# # ---------------------------------------------------------------------------
# # Model loading
# # ---------------------------------------------------------------------------
# CHECKPOINT = os.environ.get("OMNIVOICE_MODEL", "k2-fsa/OmniVoice")
#
# print(f"Loading model from {CHECKPOINT} to cuda ...")
# model = OmniVoice.from_pretrained(
#     CHECKPOINT,
#     device_map="cuda",
#     dtype=torch.float16,
#     load_asr=True,
# )
# sampling_rate = model.sampling_rate
# print("Model loaded successfully!")
#
# # ---------------------------------------------------------------------------
# # Generation logic
# # ---------------------------------------------------------------------------
#
#
# def _gen_core(
#     text,
#     language,
#     ref_audio,
#     instruct,
#     num_step,
#     guidance_scale,
#     denoise,
#     speed,
#     duration,
#     preprocess_prompt,
#     postprocess_output,
#     mode,
#     ref_text=None,
# ):
#     if not text or not text.strip():
#         return None, "Please enter the text to synthesize."
#
#     gen_config = OmniVoiceGenerationConfig(
#         num_step=int(num_step or 32),
#         guidance_scale=float(guidance_scale) if guidance_scale is not None else 2.0,
#         denoise=bool(denoise) if denoise is not None else True,
#         preprocess_prompt=bool(preprocess_prompt),
#         postprocess_output=bool(postprocess_output),
#     )
#
#     lang = language if (language and language != "Auto") else None
#
#     kw: Dict[str, Any] = dict(
#         text=text.strip(), language=lang, generation_config=gen_config
#     )
#
#     if speed is not None and float(speed) != 1.0:
#         kw["speed"] = float(speed)
#     if duration is not None and float(duration) > 0:
#         kw["duration"] = float(duration)
#
#     if mode == "clone":
#         if not ref_audio:
#             return None, "Please upload a reference audio."
#         kw["voice_clone_prompt"] = model.create_voice_clone_prompt(
#             ref_audio=ref_audio,
#             ref_text=ref_text,
#         )
#
#     if instruct and instruct.strip():
#         kw["instruct"] = instruct.strip()
#
#     try:
#         audio = model.generate(**kw)
#     except Exception as e:
#         return None, f"Error: {type(e).__name__}: {e}"
#
#     waveform = (audio[0] * 32767).astype(np.int16)
#     return (sampling_rate, waveform), "Done."
#
#
# # ---------------------------------------------------------------------------
# # ZeroGPU wrapper
# # ---------------------------------------------------------------------------
#
#
# @spaces.GPU(duration=60)
# def generate_fn(*args, **kwargs):
#     return _gen_core(*args, **kwargs)
#
#
# # ---------------------------------------------------------------------------
# # Build and launch demo
# # ---------------------------------------------------------------------------
# demo = build_demo(model, CHECKPOINT, generate_fn=generate_fn)
#
# if __name__ == "__main__":
#     demo.queue().launch()

# %%
# @title
with open('/content/OmniVoice/app.py', 'r') as f:
    content = f.read()

# Replace the line as requested
modified_content = content.replace(
    "demo.queue().launch()",
    "demo.queue().launch(share=True)"
)

with open('/content/OmniVoice/app.py', 'w') as f:
    f.write(modified_content)

# %% [markdown]
# ADD share=True
#
# TO launch()

# %%
# @title
# !python app.py
# Out:
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:300: SyntaxWarning: invalid escape sequence '\('
#   m = re.match('([su]([0-9]{1,2})p?) \(([0-9]{1,2}) bit\)$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:301: SyntaxWarning: invalid escape sequence '\('
#   m2 = re.match('([su]([0-9]{1,2})p?)( \(default\))?$', token)
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:310: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(flt)p?( \(default\))?$', token):
# /usr/local/lib/python3.12/dist-packages/pydub/utils.py:314: SyntaxWarning: invalid escape sequence '\('
#   elif re.match('(dbl)p?( \(default\))?$', token):
# Loading model from k2-fsa/OmniVoice to cuda ...
# config.json: 2.24kB [00:00, 3.15MB/s]
# model.safetensors: 100% 2.45G/2.45G [00:15<00:00, 155MB/s]
# Loading weights: 100% 313/313 [00:00<00:00, 323.23it/s]
# Downloading (incomplete total...): 0.00B [00:00, ?B/s]
# Downloading (incomplete total...):   0% 1.57k/806M [00:00<42:21:09, 5.28kB/s]
# Downloading (incomplete total...): 817MB [00:03, 298MB/s]
# Fetching 13 files: 100% 13/13 [00:03<00:00,  3.31it/s]
# Download complete: : 817MB [00:06, 136MB/s]
# Loading weights: 100% 527/527 [00:00<00:00, 1638.83it/s]
# config.json: 1.26kB [00:00, 3.78MB/s]
# model.safetensors: 100% 1.62G/1.62G [00:07<00:00, 213MB/s]
# Loading weights: 100% 587/587 [00:00<00:00, 986.47it/s]
# generation_config.json: 3.77kB [00:00, 8.95MB/s]
# tokenizer_config.json: 283kB [00:00, 47.0MB/s]
# vocab.json: 1.04MB [00:00, 14.5MB/s]
# tokenizer.json: 2.71MB [00:00, 6.95MB/s]
# merges.txt: 494kB [00:00, 8.38MB/s]
# normalizer.json: 52.7kB [00:00, 15.9MB/s]
# added_tokens.json: 34.6kB [00:00, 15.6MB/s]
# special_tokens_map.json: 2.19kB [00:00, 6.59MB/s]
# preprocessor_config.json: 100% 340/340 [00:00<00:00, 2.08MB/s]
# Model loaded successfully!
# * Running on local URL:  http://127.0.0.1:7860
# * Running on public URL: https://ab9e1848b41475430b.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# 2026-04-22 23:37:39,505 omnivoice.models.omnivoice WARNING: Reference audio is 20.5s long (>20s). This may cause slower generation, higher memory usage, and degraded voice cloning quality. We recommend trimming it to 3-10s.
# 2026-04-22 23:37:41,333 omnivoice.models.omnivoice DEBUG: Item 0 — text: This is a good day to start Thanking God. | ref_text: And a thought came and it said. If I can drink and go to the house of God and misbehave, then drinking cannot be good. Cos don't forget, for us drinking is our normal
# It wasn't odd it wasn't out of place, it wasn't frowned upon, it was our normal.
# But if can drink, and go and misbehave in God's house, drinking cannot be good. And from that day I stopped. | instruct: female | lang: en | target_tokens: 59
# 2026-04-22 23:37:59,069 omnivoice.models.omnivoice WARNING: Reference audio is 20.5s long (>20s). This may cause slower generation, higher memory usage, and degraded voice cloning quality. We recommend trimming it to 3-10s.
# 2026-04-22 23:37:59,124 omnivoice.models.omnivoice DEBUG: Item 0 — text: This is a good day to start Thanking God. | ref_text: And a thought came and it said. If I can drink and go to the house of God and misbehave, then drinking cannot be good. Cos don't forget, for us drinking is our normal
# It wasn't odd it wasn't out of place, it wasn't frowned upon, it was our normal.
# But if can drink, and go and misbehave in God's house, drinking cannot be good. And from that day I stopped. | instruct: female | lang: en | target_tokens: 59
# 2026-04-22 23:38:17,318 omnivoice.models.omnivoice WARNING: Reference audio is 20.5s long (>20s). This may cause slower generation, higher memory usage, and degraded voice cloning quality. We recommend trimming it to 3-10s.
# 2026-04-22 23:38:17,348 omnivoice.models.omnivoice DEBUG: Item 0 — text: This is a good day to start Thanking God. | ref_text: And a thought came and it said. If I can drink and go to the house of God and misbehave, then drinking cannot be good. Cos don't forget, for us drinking is our normal
# It wasn't odd it wasn't out of place, it wasn't frowned upon, it was our normal.
# But if can drink, and go and misbehave in God's house, drinking cannot be good. And from that day I stopped. | instruct: female | lang: en | target_tokens: 59
# 2026-04-22 23:39:19,828 omnivoice.models.omnivoice DEBUG: Item 0 — text: Voice Design — Create custom voices with speaker attributes | ref_text: None | instruct: female, high pitch, american accent | lang: en | target_tokens: 92
# 2026-04-22 23:39:50,900 omnivoice.models.omnivoice DEBUG: Item 0 — text: This is a good day to start Thanking God. | ref_text: None | instruct: female, high pitch, american accent | lang: en | target_tokens: 60
# 2026-04-22 23:40:07,511 omnivoice.models.omnivoice DEBUG: Item 0 — text: This is a good day to start Thanking God. | ref_text: None | instruct: female, moderate pitch, american accent | lang: en | target_tokens: 60
# 2026-04-22 23:40:22,511 omnivoice.models.omnivoice DEBUG: Item 0 — text: This is a good day to start Thanking God. | ref_text: None | instruct: female, middle-aged, moderate pitch, american accent | lang: en | target_tokens: 60
# 2026-04-22 23:40:50,123 omnivoice.models.omnivoice DEBUG: Item 0 — text: This is a good day to start Thanking God. | ref_text: None | instruct: female, elderly, moderate pitch, american accent | lang: en | target_tokens: 60
# 2026-04-22 23:41:14,965 omnivoice.models.omnivoice DEBUG: Item 0 — text: This is a good day to start Thanking God. | ref_text: None | instruct: female, elderly, moderate pitch | lang: en | target_tokens: 60
# 2026-04-22 23:41:29,898 omnivoice.models.omnivoice DEBUG: Item 0 — text: This is a good day to start Thanking God. | ref_text: None | instruct: female, elderly, low pitch | lang: en | target_tokens: 60
# 2026-04-22 23:42:43,655 omnivoice.models.omnivoice WARNING: Reference audio is 20.5s long (>20s). This may cause slower generation, higher memory usage, and degraded voice cloning quality. We recommend trimming it to 3-10s.
# 2026-04-22 23:42:43,686 omnivoice.models.omnivoice DEBUG: Item 0 — text: The Lord is my shepherd;
# I shall not [a]want.
# He makes me to lie down in [green pastures;
# He leads me beside the [still waters.
# He restores my soul;
# He leads me in the paths of righteousness
# For His name’s sake. | ref_text: And a thought came and it said. If I can drink and go to the house of God and misbehave, then drinking cannot be good. Cos don't forget, for us drinking is our normal
# It wasn't odd it wasn't out of place, it wasn't frowned upon, it was our normal.
# But if can drink, and go and misbehave in God's house, drinking cannot be good. And from that day I stopped. | instruct: female | lang: en | target_tokens: 310
# 2026-04-22 23:44:08,640 omnivoice.models.omnivoice WARNING: Reference audio is 20.5s long (>20s). This may cause slower generation, higher memory usage, and degraded voice cloning quality. We recommend trimming it to 3-10s.
# 2026-04-22 23:44:08,670 omnivoice.models.omnivoice DEBUG: Item 0 chunked into 3 pieces: ['The Lord is my shepherd;\nI shall not want.\nHe makes me to lie down in [green pastures;\nHe leads me beside the still waters.\nHe restores my soul;\nHe leads me in the paths of righteousness\nFor His name’s sake.\n\nYea,', 'though I walk through the valley of the shadow of death,\nI will fear no evil;\nFor You are with me;\nYour rod and Your staff, they comfort me.\nYou prepare a table before me in the presence of my enemies;\nYou anoint my head with oil;\nMy cup runs over.', 'Surely goodness and mercy shall follow me\nAll the days of my life;\nAnd I will [d]dwell in the house of the Lord\nForever.']
# 2026-04-22 23:44:08,670 omnivoice.models.omnivoice DEBUG: Item 0 — text: The Lord is my shepherd;
# I shall not want.
# He makes me to lie down in [green pastures;
# He leads me beside the still waters.
# He restores my soul;
# He leads me in the paths of righteousness
# For His name’s sake.
#
# Yea, | ref_text: And a thought came and it said. If I can drink and go to the house of God and misbehave, then drinking cannot be good. Cos don't forget, for us drinking is our normal
# It wasn't odd it wasn't out of place, it wasn't frowned upon, it was our normal.
# But if can drink, and go and misbehave in God's house, drinking cannot be good. And from that day I stopped. | instruct: female | lang: en | target_tokens: 315
# 2026-04-22 23:44:16,815 omnivoice.models.omnivoice DEBUG: Item 0 — text: though I walk through the valley of the shadow of death,
# I will fear no evil;
# For You are with me;
# Your rod and Your staff, they comfort me.
# You prepare a table before me in the presence of my enemies;
# You anoint my head with oil;
# My cup runs over. | ref_text: And a thought came and it said. If I can drink and go to the house of God and misbehave, then drinking cannot be good. Cos don't forget, for us drinking is our normal
# It wasn't odd it wasn't out of place, it wasn't frowned upon, it was our normal.
# But if can drink, and go and misbehave in God's house, drinking cannot be good. And from that day I stopped. | instruct: female | lang: en | target_tokens: 363
# 2026-04-22 23:44:25,978 omnivoice.models.omnivoice DEBUG: Item 0 — text: Surely goodness and mercy shall follow me
# All the days of my life;
# And I will [d]dwell in the house of the Lord
# Forever. | ref_text: And a thought came and it said. If I can drink and go to the house of God and misbehave, then drinking cannot be good. Cos don't forget, for us drinking is our normal
# It wasn't odd it wasn't out of place, it wasn't frowned upon, it was our normal.
# But if can drink, and go and misbehave in God's house, drinking cannot be good. And from that day I stopped. | instruct: female | lang: en | target_tokens: 177
# 2026-04-22 23:45:38,939 omnivoice.models.omnivoice WARNING: Reference audio is 20.5s long (>20s). This may cause slower generation, higher memory usage, and degraded voice cloning quality. We recommend trimming it to 3-10s.
# 2026-04-22 23:45:38,969 omnivoice.models.omnivoice DEBUG: Item 0 chunked into 3 pieces: ['The Lord is my shepherd;\nI shall not want.\nHe makes me to lie down in [green pastures;\nHe leads me beside the still waters.\nHe restores my soul;\nHe leads me in the paths of righteousness\nFor His name’s sake.\n\nYea,', 'though I walk through the valley of the shadow of death,\nI will fear no evil;\nFor You are with me;\nYour rod and Your staff, they comfort me.\nYou prepare a table before me in the presence of my enemies;\nYou anoint my head with oil;\nMy cup runs over.', 'Surely goodness and mercy shall follow me\nAll the days of my life;\nAnd I will [d]dwell in the house of the Lord.\nForever.']
# 2026-04-22 23:45:38,969 omnivoice.models.omnivoice DEBUG: Item 0 — text: The Lord is my shepherd;
# I shall not want.
# He makes me to lie down in [green pastures;
# He leads me beside the still waters.
# He restores my soul;
# He leads me in the paths of righteousness
# For His name’s sake.
#
# Yea, | ref_text: And a thought came and it said. If I can drink and go to the house of God and misbehave, then drinking cannot be good. Cos don't forget, for us drinking is our normal
# It wasn't odd it wasn't out of place, it wasn't frowned upon, it was our normal.
# But if can drink, and go and misbehave in God's house, drinking cannot be good. And from that day I stopped. | instruct: female | lang: en | target_tokens: 315
# 2026-04-22 23:45:46,799 omnivoice.models.omnivoice DEBUG: Item 0 — text: though I walk through the valley of the shadow of death,
# I will fear no evil;
# For You are with me;
# Your rod and Your staff, they comfort me.
# You prepare a table before me in the presence of my enemies;
# You anoint my head with oil;
# My cup runs over. | ref_text: And a thought came and it said. If I can drink and go to the house of God and misbehave, then drinking cannot be good. Cos don't forget, for us drinking is our normal
# It wasn't odd it wasn't out of place, it wasn't frowned upon, it was our normal.
# But if can drink, and go and misbehave in God's house, drinking cannot be good. And from that day I stopped. | instruct: female | lang: en | target_tokens: 363
# 2026-04-22 23:45:55,646 omnivoice.models.omnivoice DEBUG: Item 0 — text: Surely goodness and mercy shall follow me
# All the days of my life;
# And I will [d]dwell in the house of the Lord.
# Forever. | ref_text: And a thought came and it said. If I can drink and go to the house of God and misbehave, then drinking cannot be good. Cos don't forget, for us drinking is our normal
# It wasn't odd it wasn't out of place, it wasn't frowned upon, it was our normal.
# But if can drink, and go and misbehave in God's house, drinking cannot be good. And from that day I stopped. | instruct: female | lang: en | target_tokens: 178
# 2026-04-22 23:47:40,698 omnivoice.models.omnivoice WARNING: Reference audio is 20.5s long (>20s). This may cause slower generation, higher memory usage, and degraded voice cloning quality. We recommend trimming it to 3-10s.
# 2026-04-22 23:47:40,728 omnivoice.models.omnivoice DEBUG: Item 0 chunked into 3 pieces: ['The Lord is my shepherd.\nI shall not want.\nHe makes me to lie down in [green pastures.\nHe leads me beside the still waters.\nHe restores my soul.\nHe leads me in the paths of righteousness.\nFor His name’s sake.\n\nYea,', 'though I walk through the valley of the shadow of death,\nI will fear no evil.\nFor You are with me.\nYour rod and Your staff, they comfort me.\n\nYou prepare a table before me in the presence of my enemies;\nYou anoint my head with oil;\nMy cup runs over.', 'Surely goodness and mercy shall follow me\nAll the days of my life;\nAnd I will [d]dwell in the house of the Lord.\nForever.']
# 2026-04-22 23:47:40,728 omnivoice.models.omnivoice DEBUG: Item 0 — text: The Lord is my shepherd.
# I shall not want.
# He makes me to lie down in [green pastures.
# He leads me beside the still waters.
# He restores my soul.
# He leads me in the paths of righteousness.
# For His name’s sake.
#
# Yea, | ref_text: And a thought came and it said. If I can drink and go to the house of God and misbehave, then drinking cannot be good. Cos don't forget, for us drinking is our normal
# It wasn't odd it wasn't out of place, it wasn't frowned upon, it was our normal.
# But if can drink, and go and misbehave in God's house, drinking cannot be good. And from that day I stopped. | instruct: female | lang: en | target_tokens: 316
# 2026-04-22 23:47:48,811 omnivoice.models.omnivoice DEBUG: Item 0 — text: though I walk through the valley of the shadow of death,
# I will fear no evil.
# For You are with me.
# Your rod and Your staff, they comfort me.
#
# You prepare a table before me in the presence of my enemies;
# You anoint my head with oil;
# My cup runs over. | ref_text: And a thought came and it said. If I can drink and go to the house of God and misbehave, then drinking cannot be good. Cos don't forget, for us drinking is our normal
# It wasn't odd it wasn't out of place, it wasn't frowned upon, it was our normal.
# But if can drink, and go and misbehave in God's house, drinking cannot be good. And from that day I stopped. | instruct: female | lang: en | target_tokens: 365
# 2026-04-22 23:47:57,834 omnivoice.models.omnivoice DEBUG: Item 0 — text: Surely goodness and mercy shall follow me
# All the days of my life;
# And I will [d]dwell in the house of the Lord.
# Forever. | ref_text: And a thought came and it said. If I can drink and go to the house of God and misbehave, then drinking cannot be good. Cos don't forget, for us drinking is our normal
# It wasn't odd it wasn't out of place, it wasn't frowned upon, it was our normal.
# But if can drink, and go and misbehave in God's house, drinking cannot be good. And from that day I stopped. | instruct: female | lang: en | target_tokens: 178
# 2026-04-22 23:50:21,824 omnivoice.models.omnivoice WARNING: Reference audio is 20.5s long (>20s). This may cause slower generation, higher memory usage, and degraded voice cloning quality. We recommend trimming it to 3-10s.
# 2026-04-22 23:50:21,855 omnivoice.models.omnivoice DEBUG: Item 0 — text: The Lord is my shepherd.
# I shall not want.
# He makes me to lie down in [green pastures.
# He leads me beside the still waters.
# He restores my soul.
# He leads me in the paths of righteousness.
# For His name’s sake. | ref_text: And a thought came and it said. If I can drink and go to the house of God and misbehave, then drinking cannot be good. Cos don't forget, for us drinking is our normal
# It wasn't odd it wasn't out of place, it wasn't frowned upon, it was our normal.
# But if can drink, and go and misbehave in God's house, drinking cannot be good. And from that day I stopped. | instruct: female | lang: en | target_tokens: 306
# 2026-04-22 23:51:10,297 omnivoice.models.omnivoice WARNING: Reference audio is 20.5s long (>20s). This may cause slower generation, higher memory usage, and degraded voice cloning quality. We recommend trimming it to 3-10s.
# 2026-04-22 23:51:10,326 omnivoice.models.omnivoice DEBUG: Item 0 — text: Yea though I walk through the valley of the shadow of death,
# I will fear no evil.
# For You are with me.
# Your rod and Your staff, they comfort me. | ref_text: And a thought came and it said. If I can drink and go to the house of God and misbehave, then drinking cannot be good. Cos don't forget, for us drinking is our normal
# It wasn't odd it wasn't out of place, it wasn't frowned upon, it was our normal.
# But if can drink, and go and misbehave in God's house, drinking cannot be good. And from that day I stopped. | instruct: female | lang: en | target_tokens: 210
# 2026-04-22 23:51:35,485 omnivoice.models.omnivoice WARNING: Reference audio is 20.5s long (>20s). This may cause slower generation, higher memory usage, and degraded voice cloning quality. We recommend trimming it to 3-10s.
# 2026-04-22 23:51:35,515 omnivoice.models.omnivoice DEBUG: Item 0 — text: You prepare a table before me in the presence of my enemies;
# You anoint my head with oil;
# My cup runs over.
# Surely goodness and mercy shall follow me
# All the days of my life;
# And I will [d]dwell in the house of the Lord.
# Forever. | ref_text: And a thought came and it said. If I can drink and go to the house of God and misbehave, then drinking cannot be good. Cos don't forget, for us drinking is our normal
# It wasn't odd it wasn't out of place, it wasn't frowned upon, it was our normal.
# But if can drink, and go and misbehave in God's house, drinking cannot be good. And from that day I stopped. | instruct: female | lang: en | target_tokens: 337
# 2026-04-22 23:52:09,313 omnivoice.models.omnivoice WARNING: Reference audio is 20.5s long (>20s). This may cause slower generation, higher memory usage, and degraded voice cloning quality. We recommend trimming it to 3-10s.
# 2026-04-22 23:52:09,342 omnivoice.models.omnivoice DEBUG: Item 0 — text: You prepare a table before me in the presence of my enemies;
# You anoint my head with oil;
# My cup runs over.
# Surely goodness and mercy shall follow me
# All the days of my life;
# And I will [d]dwell in the house of the Lord.
# For ever. | ref_text: And a thought came and it said. If I can drink and go to the house of God and misbehave, then drinking cannot be good. Cos don't forget, for us drinking is our normal
# It wasn't odd it wasn't out of place, it wasn't frowned upon, it was our normal.
# But if can drink, and go and misbehave in God's house, drinking cannot be good. And from that day I stopped. | instruct: female | lang: en | target_tokens: 337
